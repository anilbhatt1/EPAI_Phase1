# %% [markdown]
# For this assignment, you have 4 files containing information about persons.
#
# The files are:
# * `personal_info.csv` -   personal information such as name, gender, etc. (one row per person)
# * `vehicles.csv` -   what vehicle people own (one row per person)
# * `employment.csv` -   where a person is employed (one row per person)
# * `update_status.csv` -   when the person's data was created and last updated
#
# Each file contains a key, `SSN`, which **uniquely** identifies a person.
#
# This key is present in **all** four files.
#
# You are guaranteed that the same SSN value is present in **every** file, and that it only appears **once per file**.
#
# In addition, the files are all sorted by SSN, i.e. the SSN values appear in the same order in each file.
#
# ##### Goal 1
#
# Your first task is to create iterators for each of the four files that contained cleaned up data, of the correct type (e.g. string, int, date, etc), and represented by a named tuple.
#
# For now these four iterators are just separate, independent iterators.
#
# ##### Goal 2
#
# Create a single iterable that combines all the columns from all the iterators.
#
# The iterable should yield named tuples containing all the columns.
# Make sure that the SSN's across the files match!
#
# All the files are guaranteed to be in SSN sort order, and every SSN is unique, and every SSN appears in every file.
#
# Make sure the SSN is not repeated 4 times - one time per row is enough!
#
# ##### Goal 3
#
# Next, you want to identify any stale records, where stale simply means the record has not been updated since 3/1/2017 (e.g. last update date < 3/1/2017). Create an iterator that only contains current records (i.e. not stale) based on the `last_updated` field from the `status_update` file.
#
# ##### Goal 4
#
# Find the largest group of car makes for each gender.
#
# Possibly more than one such group per gender exists (equal sizes).

# %%
import csv

# %%
personal_info = r'C:\Users\anila\Desktop\AI\EPAI-Phase1\S16_Context_Managers\personal_info.csv'
employment = r'C:\Users\anila\Desktop\AI\EPAI-Phase1\S16_Context_Managers\employment.csv'
update_status = r'C:\Users\anila\Desktop\AI\EPAI-Phase1\S16_Context_Managers\update_status.csv'
vehicles = r'C:\Users\anila\Desktop\AI\EPAI-Phase1\S16_Context_Managers\vehicles.csv'

# %% [markdown]
# # Goal1

# %% [markdown]
# **Personal_Info check**

# %%
with open(personal_info) as file:
    file_vals=iter(file)
    for i,vals in enumerate(file_vals):
        if i <= 2:
            print(vals)
    print(i)
# Out:
# ssn,first_name,last_name,gender,language
#
# 100-53-9824,Sebastiano,Tester,Male,Icelandic
#
# 101-71-4702,Cayla,MacDonagh,Female,Lao
#
# 1001

# %%
personal_info_type = ['INT', 'STRING', 'STRING', 'STRING','STRING']

# %% [markdown]
# **Vehicles check**

# %%
with open(vehicles) as file:
    file_vals=iter(file)
    for i,vals in enumerate(file_vals):
        if i <= 2:
            print(vals)
    print(i)
# Out:
# ssn,vehicle_make,vehicle_model,model_year
#
# 100-53-9824,Oldsmobile,Bravada,1993
#
# 101-71-4702,Ford,Mustang,1997
#
# 1001

# %%
vehicles_type= ['INT','STRING','STRING','INT']

# %% [markdown]
# **Employment Check**

# %%
with open(employment) as file:
    file_vals=iter(file)
    for i,vals in enumerate(file_vals):
        if i <= 2:
            print(vals)
    print(i)
# Out:
# employer,department,employee_id,ssn
#
# Abbott, Bahringer and Goyette,Marketing,41-5601892,283-04-6835
#
# Abshire Inc,Research and Development,55-8987515,868-32-1805
#
# 1001

# %%
employment_type = ['STRING','STRING','INT','INT']  # But we need to combine items like these -> Abbott, Bahringer and Goyette

# %% [markdown]
# **Update_Status Check**

# %%
with open(update_status) as file:
    file_vals=iter(file)
    for i,vals in enumerate(file_vals):
        if i <= 2:
            print(vals)
    print(i)
# Out:
# ssn,last_updated,created
#
# 100-53-9824,2017-10-07T00:14:42Z,2016-01-24T21:19:30Z
#
# 101-71-4702,2017-01-23T11:23:17Z,2016-01-27T04:32:57Z
#
# 1001

# %%
status_type = ['INT','DATE','DATE']

# %% [markdown]
# **Casting Function**

# %%
from datetime import datetime
def type_casting(col_data,input_val):
    if col_data == 'DATE':
        return datetime.strptime(input_val, '%Y-%m-%dT%H:%M:%SZ').date()
    elif col_data == 'INT':
        return int(input_val.replace('-','_'))
    else:
        return input_val

# %%
def cast_each_row(col_data_type,row_val):
    return [type_casting(col_data, value) for col_data, value in zip(col_data_type, row_val)]

# %%
from collections import namedtuple
import csv
from itertools import islice

def gen_fun(input_file,col_data_type, nt_name):
    with open(input_file) as f:
        rows = csv.reader(f, delimiter=',', quotechar='"')
        headers = next(iter(rows))
        named_tuple = namedtuple(nt_name, headers)
        for row in rows:
            if len(row) > 4 and nt_name == 'employment':
                row_new = []
                row_new.append(str(row[0] + row[1]))
                row_new.extend(row[2:])
                row = row_new
            yield named_tuple(*cast_each_row(col_data_type, row))

# %%
personal_data = gen_fun(personal_info, personal_info_type, 'personal_info')
for data in islice(personal_data, 3):
    print(data)
    personal_fields = data._fields
# Out:
# personal_info(ssn=100539824, first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# personal_info(ssn=101714702, first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# personal_info(ssn=101840356, first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')

# %%
vehicles_data = gen_fun(vehicles,vehicles_type, 'vehicles')
for data in islice(vehicles_data, 3):
    print(data)
    vehicles_fields = data._fields
# Out:
# vehicles(ssn=100539824, vehicle_make='Oldsmobile', vehicle_model='Bravada', model_year=1993)
# vehicles(ssn=101714702, vehicle_make='Ford', vehicle_model='Mustang', model_year=1997)
# vehicles(ssn=101840356, vehicle_make='GMC', vehicle_model='Yukon', model_year=2005)

# %%
status_data = gen_fun(update_status,status_type, 'update_status')
for data in islice(status_data, 3):
    print(data)
    status_fields = data._fields
# Out:
# update_status(ssn=100539824, last_updated=datetime.date(2017, 10, 7), created=datetime.date(2016, 1, 24))
# update_status(ssn=101714702, last_updated=datetime.date(2017, 1, 23), created=datetime.date(2016, 1, 27))
# update_status(ssn=101840356, last_updated=datetime.date(2017, 10, 4), created=datetime.date(2016, 9, 21))

# %%
employment_data = gen_fun(employment, employment_type, 'employment')
for data in islice(employment_data, 3):
    print(data)
    employment_fields = data._fields
# Out:
# employment(employer='Abbott Bahringer and Goyette', department='Marketing', employee_id=415601892, ssn=283046835)
# employment(employer='Abshire Inc', department='Research and Development', employee_id=558987515, ssn=868321805)
# employment(employer='Abshire-Hahn', department='Marketing', employee_id=940531814, ssn=667877090)

# %% [markdown]
# # Goal 2

# %%
print(personal_fields)
print(vehicles_fields)
print(employment_fields)
print(status_fields)
# Out:
# ('ssn', 'first_name', 'last_name', 'gender', 'language')
# ('ssn', 'vehicle_make', 'vehicle_model', 'model_year')
# ('employer', 'department', 'employee_id', 'ssn')
# ('ssn', 'last_updated', 'created')

# %%
combined_header = personal_fields + vehicles_fields[1:] + employment_fields[:-1] + status_fields[1:]
combined_header
# Out:
# ('ssn',
#  'first_name',
#  'last_name',
#  'gender',
#  'language',
#  'vehicle_make',
#  'vehicle_model',
#  'model_year',
#  'employer',
#  'department',
#  'employee_id',
#  'last_updated',
#  'created')

# %%
personal_data = gen_fun(personal_info, personal_info_type, 'personal_info')
vehicles_data = gen_fun(vehicles,vehicles_type, 'vehicles')
status_data = gen_fun(update_status,status_type, 'update_status')
employment_data = gen_fun(employment, employment_type, 'employment')

# %%
def ssn_match():
    for pers, vehi, emp, status in zip(personal_data, vehicles_data, employment_data, status_data):
        ssn_match_info = namedtuple("ssn_match_info", combined_header)
        combined_data  = [*pers] + [*vehi][1:] + [*emp][:-1] + [*status][1:]
        yield ssn_match_info(*combined_data)

# %%
ssn_matched=ssn_match()
for data in islice(ssn_matched, 1000):
    print(data)
# Out:
# ssn_match_info(ssn=100539824, first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic', vehicle_make='Oldsmobile', vehicle_model='Bravada', model_year=1993, employer='Abbott Bahringer and Goyette', department='Marketing', employee_id=415601892, last_updated=datetime.date(2017, 10, 7), created=datetime.date(2016, 1, 24))
# ssn_match_info(ssn=101714702, first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao', vehicle_make='Ford', vehicle_model='Mustang', model_year=1997, employer='Abshire Inc', department='Research and Development', employee_id=558987515, last_updated=datetime.date(2017, 1, 23), created=datetime.date(2016, 1, 27))
# ssn_match_info(ssn=101840356, first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish', vehicle_make='GMC', vehicle_model='Yukon', model_year=2005, employer='Abshire-Hahn', department='Marketing', employee_id=940531814, last_updated=datetime.date(2017, 10, 4), created=datetime.date(2016, 9, 21))
# ssn_match_info(ssn=104220928, first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi', vehicle_make='Oldsmobile', vehicle_model='Intrigue', model_year=2000, employer='Adams Deckow and Sauer', department='Services', employee_id=996082191, last_updated=datetime.date(2017, 3, 28), created=datetime.date(2016, 4, 15))
# ssn_match_info(ssn=104847144, first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans', vehicle_make='Ford', vehicle_model='Crown Victoria', model_year=2008, employer='Adams-Ledner', department='Services', employee_id=405208891, last_updated=datetime.date(2018, 2, 19), created=datetime.date(2016, 3, 15))
# ssn_match_info(ssn=105275541, first_name='Federico', last_name='Aggett', gender='Male', language='Chinese', vehicle_make='Ford', vehicle_model='Mustang', model_year=2001, employer='Altenwerth Feest and Hammes', department='Legal', employee_id=185795578, last_updated=datetime.date(2017, 7, 24), created=datetime.date(2016, 7, 23))
# ssn_match_info(ssn=105857486, first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi', vehicle_make='Chrysler', vehicle_model='300', model_year=2008, employer="Altenwerth Jacobson and O'Keefe", department='Training', employee_id=768687759, last_updated=datetime.date(2018, 2, 14), created=datetime.date(2016, 12, 15))
# ssn_match_info(ssn=105915022, first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian', vehicle_make='Isuzu', vehicle_model='Hombre Space', model_year=2000, employer='Altenwerth-Emard', department='Marketing', employee_id=305847411, last_updated=datetime.date(2018, 3, 24), created=datetime.date(2016, 3, 24))
# ssn_match_info(ssn=105917777, first_name='Audi', last_name='Roach', gender='Female', language='Estonian', vehicle_make='Chevrolet', vehicle_model='Silverado 3500', model_year=2004, employer='Altenwerth-Heidenreich', department='Research and Development', employee_id=583628686, last_updated=datetime.date(2017, 5, 11), created=datetime.date(2016, 5, 31))
# ssn_match_info(ssn=106351938, first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish', vehicle_make='GMC', vehicle_model='Sonoma Club', model_year=1992, employer='Anderson Dickinson and Toy', department='Marketing', employee_id=468501105, last_updated=datetime.date(2017, 10, 21), created=datetime.date(2016, 9, 8))
# ssn_match_info(ssn=106363293, first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin', vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008, employer='Anderson-Marks', department='Accounting', employee_id=35704062, last_updated=datetime.date(2017, 3, 18), created=datetime.date(2016, 5, 16))
# ssn_match_info(ssn=110843641, first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento', vehicle_make='Ford', vehicle_model='Mustang', model_year=1990, employer='Ankunding and Sons', department='Engineering', employee_id=500020034, last_updated=datetime.date(2017, 9, 4), created=datetime.date(2016, 9, 12))
# ssn_match_info(ssn=111351034, first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz', vehicle_make='Ford', vehicle_model='Fiesta', model_year=2001, employer='Ankunding Hintz and Kling', department='Legal', employee_id=717182616, last_updated=datetime.date(2017, 3, 18), created=datetime.date(2016, 8, 21))
# ssn_match_info(ssn=114066912, first_name='Jule', last_name='Velte', gender='Male', language='Dutch', vehicle_make='Aston Martin', vehicle_model='DBS', model_year=2011, employer='Ankunding Larson and Leannon', department='Legal', employee_id=8103537, last_updated=datetime.date(2018, 2, 5), created=datetime.date(2016, 7, 15))
# ssn_match_info(ssn=114660984, first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian', vehicle_make='Chevrolet', vehicle_model='Camaro', model_year=1998, employer='Armstrong Halvorson and Lemke', department='Services', employee_id=250791940, last_updated=datetime.date(2017, 6, 16), created=datetime.date(2016, 5, 28))
# ssn_match_info(ssn=114748701, first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic', vehicle_make='Mercedes-Benz', vehicle_model='CL65 AMG', model_year=2009, employer='Armstrong Koelpin and Moen', department='Business Development', employee_id=472658940, last_updated=datetime.date(2017, 10, 30), created=datetime.date(2016, 6, 4))
# ssn_match_info(ssn=116107235, first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari', vehicle_make='Bugatti', vehicle_model='Veyron', model_year=2009, employer='Armstrong-VonRueden', department='Support', employee_id=645533135, last_updated=datetime.date(2017, 3, 10), created=datetime.date(2016, 10, 17))
# ssn_match_info(ssn=116774915, first_name='Herold', last_name='Fearon', gender='Male', language='Italian', vehicle_make='Buick', vehicle_model='Rainier', model_year=2004, employer='Auer Group', department='Human Resources', employee_id=964407720, last_updated=datetime.date(2017, 11, 21), created=datetime.date(2016, 7, 3))
# ssn_match_info(ssn=117396617, first_name='Auroora', last_name='Yong', gender='Female', language='Swahili', vehicle_make='Scion', vehicle_model='tC', model_year=2008, employer='Auer-Kiehn', department='Accounting', employee_id=83656779, last_updated=datetime.date(2017, 9, 1), created=datetime.date(2016, 12, 1))
# ssn_match_info(ssn=117779748, first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew', vehicle_make='Audi', vehicle_model='S6', model_year=2009, employer='Aufderhar Inc', department='Services', employee_id=736733606, last_updated=datetime.date(2017, 2, 18), created=datetime.date(2016, 2, 2))
# ssn_match_info(ssn=117786202, first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish', vehicle_make='Rolls-Royce', vehicle_model='Phantom', model_year=2007, employer='Aufderhar Metz and Bashirian', department='Business Development', employee_id=682399289, last_updated=datetime.date(2017, 11, 2), created=datetime.date(2016, 4, 18))
# ssn_match_info(ssn=118210357, first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian', vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1992, employer='Aufderhar Quigley and Wiza', department='Research and Development', employee_id=879571848, last_updated=datetime.date(2017, 12, 13), created=datetime.date(2016, 10, 24))
# ssn_match_info(ssn=118957100, first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian', vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993, employer='Aufderhar Trantow and Goodwin', department='Marketing', employee_id=708647485, last_updated=datetime.date(2017, 4, 25), created=datetime.date(2016, 1, 29))
# ssn_match_info(ssn=119078817, first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian', vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2005, employer='Bahringer Jacobs and Schimmel', department='Marketing', employee_id=930656725, last_updated=datetime.date(2017, 12, 24), created=datetime.date(2016, 12, 6))
# ssn_match_info(ssn=120335535, first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi', vehicle_make='Isuzu', vehicle_model='Trooper', model_year=1997, employer='Bahringer Pacocha and Ritchie', department='Engineering', employee_id=927514376, last_updated=datetime.date(2017, 11, 11), created=datetime.date(2016, 7, 10))
# ssn_match_info(ssn=120984054, first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh', vehicle_make='Acura', vehicle_model='RL', model_year=2003, employer='Balistreri Inc', department='Sales', employee_id=928183627, last_updated=datetime.date(2017, 12, 1), created=datetime.date(2016, 7, 23))
# ssn_match_info(ssn=121983948, first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian', vehicle_make='Pontiac', vehicle_model='Montana', model_year=2002, employer='Balistreri Inc', department='Human Resources', employee_id=625455166, last_updated=datetime.date(2017, 8, 23), created=datetime.date(2016, 6, 26))
# ssn_match_info(ssn=123053229, first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian', vehicle_make='Jaguar', vehicle_model='X-Type', model_year=2003, employer='Barrows Inc', department='Product Management', employee_id=63741043, last_updated=datetime.date(2017, 8, 16), created=datetime.date(2016, 10, 23))
# ssn_match_info(ssn=123622832, first_name='Kare', last_name='Barhams', gender='Female', language='Tajik', vehicle_make='Cadillac', vehicle_model='Catera', model_year=1999, employer='Barrows Koelpin and Wehner', department='Research and Development', employee_id=218725671, last_updated=datetime.date(2017, 9, 11), created=datetime.date(2016, 10, 22))
# ssn_match_info(ssn=123883381, first_name='Christiane', last_name='Hynes', gender='Female', language='Danish', vehicle_make='Ford', vehicle_model='Mustang', model_year=1989, employer='Barrows-Schroeder', department='Engineering', employee_id=503503684, last_updated=datetime.date(2017, 2, 21), created=datetime.date(2016, 1, 30))
# ssn_match_info(ssn=125079434, first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian', vehicle_make='Lexus', vehicle_model='RX', model_year=2010, employer='Bartell Inc', department='Support', employee_id=662492097, last_updated=datetime.date(2017, 2, 7), created=datetime.date(2016, 7, 8))
# ssn_match_info(ssn=127492473, first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole', vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2004, employer='Bartell Brakus and Considine', department='Marketing', employee_id=763802991, last_updated=datetime.date(2017, 8, 31), created=datetime.date(2016, 8, 29))
# ssn_match_info(ssn=127528001, first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara', vehicle_make='Porsche', vehicle_model='Cayenne', model_year=2008, employer='Bartell Friesen and Lakin', department='Sales', employee_id=807946674, last_updated=datetime.date(2017, 1, 12), created=datetime.date(2016, 10, 9))
# ssn_match_info(ssn=127684232, first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic', vehicle_make='Scion', vehicle_model='xB', model_year=2004, employer='Bartell-Gerlach', department='Legal', employee_id=841354848, last_updated=datetime.date(2017, 3, 20), created=datetime.date(2016, 8, 19))
# ssn_match_info(ssn=127933548, first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao', vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=2007, employer='Bartoletti Inc', department='Support', employee_id=777239839, last_updated=datetime.date(2017, 9, 10), created=datetime.date(2016, 7, 23))
# ssn_match_info(ssn=128424599, first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian', vehicle_make='Chevrolet', vehicle_model='Avalanche 1500', model_year=2006, employer='Bartoletti Rice and Conn', department='Support', employee_id=605481083, last_updated=datetime.date(2017, 1, 29), created=datetime.date(2016, 7, 13))
# ssn_match_info(ssn=128530369, first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian', vehicle_make='Audi', vehicle_model='A4', model_year=2010, employer='Bartoletti-Cole', department='Training', employee_id=891531099, last_updated=datetime.date(2017, 8, 10), created=datetime.date(2016, 12, 19))
# ssn_match_info(ssn=128537952, first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish', vehicle_make='Dodge', vehicle_model='Neon', model_year=1995, employer='Barton-Raynor', department='Legal', employee_id=864272610, last_updated=datetime.date(2017, 8, 31), created=datetime.date(2016, 7, 29))
# ssn_match_info(ssn=128566040, first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian', vehicle_make='BMW', vehicle_model='M', model_year=2001, employer='Bashirian Group', department='Legal', employee_id=674961160, last_updated=datetime.date(2017, 8, 13), created=datetime.date(2016, 3, 21))
# ssn_match_info(ssn=128604388, first_name='Norton', last_name='Shailer', gender='Male', language='Czech', vehicle_make='Buick', vehicle_model='Skyhawk', model_year=1988, employer='Bashirian Beer and Bailey', department='Engineering', employee_id=383479804, last_updated=datetime.date(2017, 1, 3), created=datetime.date(2016, 3, 18))
# ssn_match_info(ssn=129670291, first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha', vehicle_make='Lotus', vehicle_model='Esprit', model_year=1993, employer='Bashirian-Lueilwitz', department='Engineering', employee_id=443328799, last_updated=datetime.date(2017, 2, 11), created=datetime.date(2016, 12, 12))
# ssn_match_info(ssn=131814310, first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish', vehicle_make='Land Rover', vehicle_model='Range Rover Sport', model_year=2012, employer='Bashirian-Moen', department='Training', employee_id=519115041, last_updated=datetime.date(2018, 3, 21), created=datetime.date(2016, 2, 3))
# ssn_match_info(ssn=132263507, first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi', vehicle_make='Dodge', vehicle_model='Ramcharger', model_year=1992, employer='Batz Inc', department='Support', employee_id=492738721, last_updated=datetime.date(2017, 1, 19), created=datetime.date(2016, 5, 20))
# ssn_match_info(ssn=134050120, first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino', vehicle_make='BMW', vehicle_model='M5', model_year=2006, employer='Batz-Bahringer', department='Research and Development', employee_id=741907423, last_updated=datetime.date(2017, 1, 29), created=datetime.date(2016, 8, 3))
# ssn_match_info(ssn=135869625, first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz', vehicle_make='Toyota', vehicle_model='Tundra', model_year=2004, employer='Batz-Effertz', department='Marketing', employee_id=476735310, last_updated=datetime.date(2017, 12, 22), created=datetime.date(2016, 2, 28))
# ssn_match_info(ssn=137131889, first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama', vehicle_make='Infiniti', vehicle_model='G', model_year=2005, employer='Bauch Group', department='Legal', employee_id=147760557, last_updated=datetime.date(2017, 12, 24), created=datetime.date(2016, 3, 1))
# ssn_match_info(ssn=138654579, first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish', vehicle_make='Oldsmobile', vehicle_model='Achieva', model_year=1992, employer='Bauch Inc', department='Business Development', employee_id=840420516, last_updated=datetime.date(2017, 4, 17), created=datetime.date(2016, 12, 17))
# ssn_match_info(ssn=138671198, first_name='Pam', last_name='Tofful', gender='Female', language='Bislama', vehicle_make='Lexus', vehicle_model='RX', model_year=2003, employer='Bauch LLC', department='Services', employee_id=876743338, last_updated=datetime.date(2018, 3, 4), created=datetime.date(2016, 9, 24))
# ssn_match_info(ssn=138885288, first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese', vehicle_make='Mercury', vehicle_model='Monterey', model_year=2004, employer='Bauch Monahan and Hagenes', department='Sales', employee_id=449784881, last_updated=datetime.date(2017, 2, 24), created=datetime.date(2016, 1, 4))
# ssn_match_info(ssn=139048189, first_name='Stirling', last_name='Creak', gender='Male', language='Italian', vehicle_make='Ford', vehicle_model='Escort', model_year=1997, employer='Baumbach Group', department='Human Resources', employee_id=937798424, last_updated=datetime.date(2017, 2, 16), created=datetime.date(2016, 5, 24))
# ssn_match_info(ssn=139945865, first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole', vehicle_make='Volkswagen', vehicle_model='Cabriolet', model_year=1990, employer='Baumbach Jenkins and Russel', department='Product Management', employee_id=394882068, last_updated=datetime.date(2017, 8, 19), created=datetime.date(2016, 9, 10))
# ssn_match_info(ssn=139996417, first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi', vehicle_make='Volvo', vehicle_model='V70', model_year=2002, employer='Bayer-Kunze', department='Support', employee_id=866996270, last_updated=datetime.date(2018, 1, 17), created=datetime.date(2016, 12, 21))
# ssn_match_info(ssn=140339727, first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian', vehicle_make='Mitsubishi', vehicle_model='Lancer', model_year=2003, employer='Beahan-Little', department='Sales', employee_id=701386102, last_updated=datetime.date(2017, 9, 21), created=datetime.date(2016, 1, 27))
# ssn_match_info(ssn=140588263, first_name='Tim', last_name='Bergin', gender='Female', language='Maori', vehicle_make='Volvo', vehicle_model='XC90', model_year=2009, employer='Beatty and Sons', department='Sales', employee_id=719137028, last_updated=datetime.date(2017, 11, 12), created=datetime.date(2016, 12, 14))
# ssn_match_info(ssn=141150543, first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin', vehicle_make='Toyota', vehicle_model='Corolla', model_year=2000, employer='Beatty Mohr and Wolff', department='Support', employee_id=466432775, last_updated=datetime.date(2017, 9, 27), created=datetime.date(2016, 7, 17))
# ssn_match_info(ssn=141889721, first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana', vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011, employer='Beatty-Stoltenberg', department='Training', employee_id=803893845, last_updated=datetime.date(2018, 1, 24), created=datetime.date(2016, 12, 20))
# ssn_match_info(ssn=142774616, first_name='Barron', last_name='Victoria', gender='Male', language='Assamese', vehicle_make='Chevrolet', vehicle_model='Prizm', model_year=1999, employer='Bechtelar-Cartwright', department='Legal', employee_id=597811224, last_updated=datetime.date(2017, 7, 16), created=datetime.date(2016, 7, 30))
# ssn_match_info(ssn=142873416, first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik', vehicle_make='Ford', vehicle_model='Thunderbird', model_year=2005, employer='Bechtelar-McCullough', department='Sales', employee_id=11786654, last_updated=datetime.date(2017, 5, 3), created=datetime.date(2016, 12, 26))
# ssn_match_info(ssn=143174714, first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek', vehicle_make='Nissan', vehicle_model='Frontier', model_year=1999, employer='Becker Inc', department='Product Management', employee_id=918337873, last_updated=datetime.date(2017, 7, 21), created=datetime.date(2016, 2, 9))
# ssn_match_info(ssn=145108454, first_name='Donny', last_name='Laba', gender='Male', language='Japanese', vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999, employer='Becker Ferry and Kulas', department='Human Resources', employee_id=830034047, last_updated=datetime.date(2017, 1, 18), created=datetime.date(2016, 4, 25))
# ssn_match_info(ssn=145355124, first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi', vehicle_make='GMC', vehicle_model='Savana 1500', model_year=1999, employer='Becker-Bogisich', department='Research and Development', employee_id=23341550, last_updated=datetime.date(2018, 2, 20), created=datetime.date(2016, 10, 3))
# ssn_match_info(ssn=145783985, first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian', vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1993, employer='Bednar LLC', department='Support', employee_id=166342889, last_updated=datetime.date(2017, 6, 10), created=datetime.date(2016, 9, 23))
# ssn_match_info(ssn=146813446, first_name='Korry', last_name='Billham', gender='Female', language='Hebrew', vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1988, employer='Bednar-Senger', department='Legal', employee_id=431692930, last_updated=datetime.date(2017, 1, 18), created=datetime.date(2016, 9, 1))
# ssn_match_info(ssn=147331463, first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento', vehicle_make='GMC', vehicle_model='Vandura G1500', model_year=1995, employer='Bednar-Stanton', department='Human Resources', employee_id=618045719, last_updated=datetime.date(2018, 2, 9), created=datetime.date(2016, 5, 31))
# ssn_match_info(ssn=147478577, first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati', vehicle_make='Mitsubishi', vehicle_model='GTO', model_year=1996, employer='Beer Inc', department='Engineering', employee_id=543652698, last_updated=datetime.date(2017, 4, 2), created=datetime.date(2016, 12, 11))
# ssn_match_info(ssn=147633462, first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin', vehicle_make='Ford', vehicle_model='Explorer', model_year=2005, employer='Beer-Homenick', department='Accounting', employee_id=105534710, last_updated=datetime.date(2018, 2, 2), created=datetime.date(2016, 7, 17))
# ssn_match_info(ssn=148607519, first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer', vehicle_make='Mitsubishi', vehicle_model='RVR', model_year=1992, employer='Beer-Kihn', department='Support', employee_id=515485483, last_updated=datetime.date(2017, 1, 22), created=datetime.date(2016, 4, 29))
# ssn_match_info(ssn=149187272, first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento', vehicle_make='Mercedes-Benz', vehicle_model='500SEL', model_year=1992, employer='Beer-Nitzsche', department='Product Management', employee_id=908245850, last_updated=datetime.date(2017, 8, 31), created=datetime.date(2016, 10, 21))
# ssn_match_info(ssn=149456482, first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian', vehicle_make='GMC', vehicle_model='3500 Club Coupe', model_year=1995, employer='Beier Stroman and Davis', department='Engineering', employee_id=374950737, last_updated=datetime.date(2017, 9, 2), created=datetime.date(2016, 2, 23))
# ssn_match_info(ssn=150646357, first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian', vehicle_make='Cadillac', vehicle_model='Escalade', model_year=2000, employer='Berge-Davis', department='Services', employee_id=365486054, last_updated=datetime.date(2018, 2, 14), created=datetime.date(2016, 1, 28))
# ssn_match_info(ssn=150893343, first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha', vehicle_make='Plymouth', vehicle_model='Laser', model_year=1993, employer='Berge-Schimmel', department='Business Development', employee_id=277571787, last_updated=datetime.date(2017, 6, 4), created=datetime.date(2016, 4, 23))
# ssn_match_info(ssn=151543946, first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali', vehicle_make='Ford', vehicle_model='Probe', model_year=1996, employer='Berge-Wiza', department='Product Management', employee_id=675791221, last_updated=datetime.date(2018, 2, 8), created=datetime.date(2016, 10, 19))
# ssn_match_info(ssn=151700641, first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy', vehicle_make='Ford', vehicle_model='F250', model_year=1999, employer='Bergnaum and Sons', department='Engineering', employee_id=234135932, last_updated=datetime.date(2017, 2, 13), created=datetime.date(2016, 4, 28))
# ssn_match_info(ssn=151781397, first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho', vehicle_make='BMW', vehicle_model='M5', model_year=2000, employer='Bergnaum Funk and Huel', department='Legal', employee_id=95871313, last_updated=datetime.date(2017, 7, 8), created=datetime.date(2016, 6, 11))
# ssn_match_info(ssn=152713526, first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish', vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2001, employer='Bergnaum Thiel and Kihn', department='Training', employee_id=459507418, last_updated=datetime.date(2018, 2, 25), created=datetime.date(2016, 10, 8))
# ssn_match_info(ssn=153671309, first_name='Annelise', last_name='Yushin', gender='Female', language='French', vehicle_make='Ford', vehicle_model='Taurus', model_year=1998, employer='Bergstrom-Boyle', department='Marketing', employee_id=723121170, last_updated=datetime.date(2017, 8, 16), created=datetime.date(2016, 12, 22))
# ssn_match_info(ssn=154177912, first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi', vehicle_make='Nissan', vehicle_model='Armada', model_year=2005, employer='Bergstrom-Daniel', department='Marketing', employee_id=317381298, last_updated=datetime.date(2017, 4, 19), created=datetime.date(2016, 1, 29))
# ssn_match_info(ssn=156187547, first_name='Trey', last_name='Payne', gender='Male', language='West Frisian', vehicle_make='Subaru', vehicle_model='Legacy', model_year=2011, employer='Bernier Inc', department='Product Management', employee_id=632531739, last_updated=datetime.date(2017, 9, 10), created=datetime.date(2016, 10, 20))
# ssn_match_info(ssn=156916848, first_name='Carol', last_name='Cromar', gender='Female', language='Amharic', vehicle_make='Acura', vehicle_model='TL', model_year=2005, employer='Bernier Ruecker and Carroll', department='Services', employee_id=690108218, last_updated=datetime.date(2017, 8, 30), created=datetime.date(2016, 5, 7))
# ssn_match_info(ssn=157179982, first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish', vehicle_make='Audi', vehicle_model='Q7', model_year=2007, employer='Bins-Gerhold', department='Sales', employee_id=899965641, last_updated=datetime.date(2017, 4, 17), created=datetime.date(2016, 3, 17))
# ssn_match_info(ssn=157387090, first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans', vehicle_make='Dodge', vehicle_model='Dakota Club', model_year=2005, employer='Blanda LLC', department='Business Development', employee_id=922526945, last_updated=datetime.date(2017, 3, 24), created=datetime.date(2016, 9, 15))
# ssn_match_info(ssn=157515269, first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi', vehicle_make='BMW', vehicle_model='Z3', model_year=1996, employer='Blanda Marks and Metz', department='Training', employee_id=810398914, last_updated=datetime.date(2017, 11, 4), created=datetime.date(2016, 6, 17))
# ssn_match_info(ssn=161369710, first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish', vehicle_make='Mercedes-Benz', vehicle_model='SLK-Class', model_year=1999, employer='Blanda Yundt and Swaniawski', department='Support', employee_id=840216207, last_updated=datetime.date(2017, 7, 3), created=datetime.date(2016, 6, 9))
# ssn_match_info(ssn=161534778, first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz', vehicle_make='Ford', vehicle_model='Mustang', model_year=1995, employer='Blanda-Ferry', department='Product Management', employee_id=749087432, last_updated=datetime.date(2017, 12, 3), created=datetime.date(2016, 12, 9))
# ssn_match_info(ssn=163688070, first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino', vehicle_make='Lincoln', vehicle_model='Continental', model_year=1998, employer='Block Doyle and Waelchi', department='Product Management', employee_id=659497375, last_updated=datetime.date(2017, 9, 6), created=datetime.date(2016, 10, 23))
# ssn_match_info(ssn=163981022, first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian', vehicle_make='Honda', vehicle_model='Civic', model_year=2012, employer='Bode-Zulauf', department='Marketing', employee_id=420021775, last_updated=datetime.date(2017, 3, 26), created=datetime.date(2016, 3, 22))
# ssn_match_info(ssn=164119849, first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=2001, employer='Boehm Goldner and Wisozk', department='Sales', employee_id=299226065, last_updated=datetime.date(2017, 6, 24), created=datetime.date(2016, 4, 20))
# ssn_match_info(ssn=166104488, first_name='Lester', last_name='Keyson', gender='Male', language='Bislama', vehicle_make='Cadillac', vehicle_model='DTS', model_year=2008, employer='Boehm Stamm and Skiles', department='Training', employee_id=892845429, last_updated=datetime.date(2017, 8, 14), created=datetime.date(2016, 7, 2))
# ssn_match_info(ssn=167392377, first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese', vehicle_make='GMC', vehicle_model='3500', model_year=1998, employer='Boehm-Schaefer', department='Human Resources', employee_id=603540943, last_updated=datetime.date(2017, 10, 31), created=datetime.date(2016, 2, 3))
# ssn_match_info(ssn=168025324, first_name='Dane', last_name='Cornick', gender='Male', language='Tajik', vehicle_make='Volkswagen', vehicle_model='Fox', model_year=1989, employer='Bogan Stamm and Donnelly', department='Legal', employee_id=362545788, last_updated=datetime.date(2018, 1, 4), created=datetime.date(2016, 1, 29))
# ssn_match_info(ssn=168198754, first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian', vehicle_make='Toyota', vehicle_model='MR2', model_year=1993, employer='Bogisich Inc', department='Human Resources', employee_id=347172919, last_updated=datetime.date(2017, 6, 10), created=datetime.date(2016, 9, 27))
# ssn_match_info(ssn=168810838, first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara', vehicle_make='Mazda', vehicle_model='Mazda5', model_year=2012, employer='Bogisich-Turcotte', department='Support', employee_id=351341288, last_updated=datetime.date(2017, 2, 11), created=datetime.date(2016, 9, 19))
# ssn_match_info(ssn=168896661, first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum', vehicle_make='Chevrolet', vehicle_model='Corvette', model_year=1964, employer='Bosco-Kunde', department='Services', employee_id=551726090, last_updated=datetime.date(2017, 7, 17), created=datetime.date(2016, 4, 30))
# ssn_match_info(ssn=170653388, first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese', vehicle_make='Dodge', vehicle_model='Caravan', model_year=2010, employer='Botsford Lockman and Schiller', department='Engineering', employee_id=854893521, last_updated=datetime.date(2017, 3, 5), created=datetime.date(2016, 6, 15))
# ssn_match_info(ssn=171277781, first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao', vehicle_make='Ford', vehicle_model='Mustang', model_year=1985, employer='Boyer Gorczany and Langosh', department='Research and Development', employee_id=879179375, last_updated=datetime.date(2017, 3, 5), created=datetime.date(2016, 9, 23))
# ssn_match_info(ssn=172237739, first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz', vehicle_make='Mazda', vehicle_model='Mazdaspeed 3', model_year=2011, employer='Boyer Hermann and Bayer', department='Legal', employee_id=452093562, last_updated=datetime.date(2018, 3, 2), created=datetime.date(2016, 5, 12))
# ssn_match_info(ssn=172774263, first_name='Alex', last_name='Udie', gender='Male', language='French', vehicle_make='Volvo', vehicle_model='S60', model_year=2002, employer='Boyer Mueller and Boyer', department='Engineering', employee_id=199999045, last_updated=datetime.date(2017, 10, 11), created=datetime.date(2016, 9, 10))
# ssn_match_info(ssn=172897546, first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian', vehicle_make='Mercury', vehicle_model='Cougar', model_year=1969, employer='Boyle LLC', department='Engineering', employee_id=986205708, last_updated=datetime.date(2017, 1, 25), created=datetime.date(2016, 7, 24))
# ssn_match_info(ssn=173997372, first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish', vehicle_make='Kia', vehicle_model='Sephia', model_year=1997, employer='Boyle Rutherford and Parisian', department='Legal', employee_id=368081521, last_updated=datetime.date(2018, 3, 3), created=datetime.date(2016, 10, 26))
# ssn_match_info(ssn=174132047, first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu', vehicle_make='Mitsubishi', vehicle_model='L300', model_year=1988, employer='Boyle-Gleichner', department='Legal', employee_id=459409049, last_updated=datetime.date(2017, 1, 28), created=datetime.date(2016, 1, 12))
# ssn_match_info(ssn=174353812, first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz', vehicle_make='Ford', vehicle_model='Thunderbird', model_year=1972, employer='Brakus and Sons', department='Marketing', employee_id=778475594, last_updated=datetime.date(2017, 1, 25), created=datetime.date(2016, 5, 14))
# ssn_match_info(ssn=174519992, first_name='Drucie', last_name='Travers', gender='Female', language='Swati', vehicle_make='Chevrolet', vehicle_model='Beretta', model_year=1994, employer='Brakus Towne and Connelly', department='Support', employee_id=982184361, last_updated=datetime.date(2017, 3, 3), created=datetime.date(2016, 5, 17))
# ssn_match_info(ssn=174872537, first_name='Benton', last_name='Nolte', gender='Male', language='Persian', vehicle_make='Ford', vehicle_model='Taurus', model_year=1991, employer="Brakus-D'Amore", department='Human Resources', employee_id=670234629, last_updated=datetime.date(2017, 9, 30), created=datetime.date(2016, 8, 1))
# ssn_match_info(ssn=176821359, first_name='Corny', last_name='Rothera', gender='Female', language='Thai', vehicle_make='Toyota', vehicle_model='Celica', model_year=1995, employer='Braun Inc', department='Engineering', employee_id=747470747, last_updated=datetime.date(2017, 1, 14), created=datetime.date(2016, 11, 29))
# ssn_match_info(ssn=176995851, first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan', vehicle_make='Jeep', vehicle_model='Commander', model_year=2007, employer='Breitenberg-Durgan', department='Human Resources', employee_id=743440904, last_updated=datetime.date(2017, 4, 1), created=datetime.date(2016, 12, 3))
# ssn_match_info(ssn=179882790, first_name='Errick', last_name='Charsley', gender='Male', language='Japanese', vehicle_make='Chevrolet', vehicle_model='Malibu', model_year=2013, employer='Breitenberg-Wiza', department='Accounting', employee_id=556401615, last_updated=datetime.date(2017, 3, 23), created=datetime.date(2016, 3, 6))
# ssn_match_info(ssn=181074434, first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan', vehicle_make='Chevrolet', vehicle_model='Impala SS', model_year=1995, employer='Brekke Grady and Ruecker', department='Human Resources', employee_id=662984352, last_updated=datetime.date(2017, 10, 7), created=datetime.date(2016, 11, 11))
# ssn_match_info(ssn=181288337, first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan', vehicle_make='GMC', vehicle_model='Canyon', model_year=2004, employer='Brekke Graham and Hilll', department='Product Management', employee_id=988943921, last_updated=datetime.date(2017, 11, 30), created=datetime.date(2016, 4, 27))
# ssn_match_info(ssn=181886077, first_name='Ebba', last_name='Wozencroft', gender='Female', language='German', vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2008, employer='Brekke-Rippin', department='Services', employee_id=16025412, last_updated=datetime.date(2017, 8, 16), created=datetime.date(2016, 9, 15))
# ssn_match_info(ssn=182155082, first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili', vehicle_make='Mercedes-Benz', vehicle_model='S-Class', model_year=1988, employer='Brown Group', department='Accounting', employee_id=910435820, last_updated=datetime.date(2017, 10, 2), created=datetime.date(2016, 10, 16))
# ssn_match_info(ssn=182814541, first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish', vehicle_make='Jeep', vehicle_model='Grand Cherokee', model_year=1997, employer='Brown Inc', department='Accounting', employee_id=688035288, last_updated=datetime.date(2017, 7, 5), created=datetime.date(2016, 7, 23))
# ssn_match_info(ssn=183105024, first_name='Curran', last_name='Squires', gender='Male', language='Romanian', vehicle_make='Maserati', vehicle_model='Spyder', model_year=1991, employer='Brown-Greenfelder', department='Services', employee_id=304548148, last_updated=datetime.date(2017, 11, 3), created=datetime.date(2016, 9, 8))
# ssn_match_info(ssn=184606243, first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin', vehicle_make='Ford', vehicle_model='Mustang', model_year=1998, employer='Carroll and Sons', department='Marketing', employee_id=960367474, last_updated=datetime.date(2018, 2, 26), created=datetime.date(2016, 6, 16))
# ssn_match_info(ssn=184841003, first_name='Bary', last_name='Buzin', gender='Male', language='Aymara', vehicle_make='Mercury', vehicle_model='Mystique', model_year=1997, employer='Carroll Konopelski and Wunsch', department='Research and Development', employee_id=434797129, last_updated=datetime.date(2017, 10, 15), created=datetime.date(2016, 11, 17))
# ssn_match_info(ssn=184923560, first_name='Kore', last_name='Eastes', gender='Female', language='Fijian', vehicle_make='Scion', vehicle_model='xD', model_year=2011, employer='Carroll Skiles and McDermott', department='Engineering', employee_id=594324075, last_updated=datetime.date(2017, 2, 16), created=datetime.date(2016, 7, 26))
# ssn_match_info(ssn=184945241, first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati', vehicle_make='Audi', vehicle_model='90', model_year=1991, employer='Carroll Treutel and Kub', department='Research and Development', employee_id=839766179, last_updated=datetime.date(2017, 3, 28), created=datetime.date(2016, 6, 3))
# ssn_match_info(ssn=185500434, first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua', vehicle_make='Suzuki', vehicle_model='X-90', model_year=1998, employer='Carroll-Tillman', department='Services', employee_id=917097850, last_updated=datetime.date(2017, 2, 19), created=datetime.date(2016, 10, 24))
# ssn_match_info(ssn=185849868, first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho', vehicle_make='Mercury', vehicle_model='Sable', model_year=2001, employer='Carter Padberg and Stiedemann', department='Support', employee_id=447764644, last_updated=datetime.date(2017, 7, 1), created=datetime.date(2016, 8, 8))
# ssn_match_info(ssn=186657773, first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi', vehicle_make='Mitsubishi', vehicle_model='Precis', model_year=1990, employer='Carter-Parker', department='Support', employee_id=405571895, last_updated=datetime.date(2017, 6, 9), created=datetime.date(2016, 9, 17))
# ssn_match_info(ssn=188209317, first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai', vehicle_make='Chevrolet', vehicle_model='Avalanche 2500', model_year=2003, employer='Cartwright Schowalter and Barton', department='Marketing', employee_id=155191499, last_updated=datetime.date(2017, 12, 26), created=datetime.date(2016, 6, 5))
# ssn_match_info(ssn=188404336, first_name='Belita', last_name='Camolli', gender='Female', language='Telugu', vehicle_make='Mercedes-Benz', vehicle_model='E-Class', model_year=1985, employer='Cartwright-Emmerich', department='Marketing', employee_id=331047074, last_updated=datetime.date(2017, 12, 27), created=datetime.date(2016, 6, 30))
# ssn_match_info(ssn=189265696, first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin', vehicle_make='BMW', vehicle_model='8 Series', model_year=1995, employer='Casper Inc', department='Services', employee_id=119251197, last_updated=datetime.date(2017, 8, 8), created=datetime.date(2016, 9, 9))
# ssn_match_info(ssn=189491458, first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua', vehicle_make='Volkswagen', vehicle_model='Touareg', model_year=2008, employer='Casper Leannon and Davis', department='Services', employee_id=308794616, last_updated=datetime.date(2017, 2, 12), created=datetime.date(2016, 6, 21))
# ssn_match_info(ssn=190056987, first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian', vehicle_make='Subaru', vehicle_model='Legacy', model_year=1990, employer='Casper Ward and Gleason', department='Marketing', employee_id=75724630, last_updated=datetime.date(2017, 6, 6), created=datetime.date(2016, 2, 17))
# ssn_match_info(ssn=190534517, first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili', vehicle_make='Hyundai', vehicle_model='Sonata', model_year=1993, employer='Cassin Batz and Altenwerth', department='Services', employee_id=529445859, last_updated=datetime.date(2018, 2, 12), created=datetime.date(2016, 4, 15))
# ssn_match_info(ssn=191153194, first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai', vehicle_make='Mercury', vehicle_model='Grand Marquis', model_year=2009, employer='Christiansen LLC', department='Sales', employee_id=661175841, last_updated=datetime.date(2017, 7, 27), created=datetime.date(2016, 5, 23))
# ssn_match_info(ssn=192540695, first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori', vehicle_make='Volvo', vehicle_model='C70', model_year=1998, employer='Christiansen Conroy and Hettinger', department='Research and Development', employee_id=965661085, last_updated=datetime.date(2017, 3, 18), created=datetime.date(2016, 11, 16))
# ssn_match_info(ssn=192673201, first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew', vehicle_make='Mitsubishi', vehicle_model='Galant', model_year=1999, employer="Christiansen Ondricka and O'Connell", department='Marketing', employee_id=327034344, last_updated=datetime.date(2017, 1, 19), created=datetime.date(2016, 6, 13))
# ssn_match_info(ssn=194765816, first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic', vehicle_make='Dodge', vehicle_model='Dakota', model_year=2001, employer='Christiansen-Koch', department='Support', employee_id=739719343, last_updated=datetime.date(2017, 1, 16), created=datetime.date(2016, 5, 26))
# ssn_match_info(ssn=195235731, first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese', vehicle_make='Saturn', vehicle_model='Outlook', model_year=2007, employer='Cole Deckow and Schiller', department='Engineering', employee_id=64130016, last_updated=datetime.date(2017, 5, 22), created=datetime.date(2016, 10, 23))
# ssn_match_info(ssn=196693796, first_name='Marijo', last_name='Tester', gender='Female', language='Oriya', vehicle_make='Subaru', vehicle_model='Legacy', model_year=2007, employer='Cole-Reinger', department='Accounting', employee_id=641589266, last_updated=datetime.date(2017, 1, 23), created=datetime.date(2016, 8, 1))
# ssn_match_info(ssn=198706443, first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian', vehicle_make='Infiniti', vehicle_model='QX', model_year=2005, employer='Collier Inc', department='Research and Development', employee_id=815101189, last_updated=datetime.date(2017, 2, 13), created=datetime.date(2016, 1, 22))
# ssn_match_info(ssn=199450804, first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana', vehicle_make='Suzuki', vehicle_model='XL-7', model_year=2003, employer='Collier Botsford and Ruecker', department='Engineering', employee_id=185849664, last_updated=datetime.date(2017, 6, 23), created=datetime.date(2016, 11, 7))
# ssn_match_info(ssn=199544639, first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali', vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2006, employer='Collier Hilll and Hagenes', department='Training', employee_id=156651242, last_updated=datetime.date(2018, 2, 23), created=datetime.date(2016, 4, 5))
# ssn_match_info(ssn=200817151, first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali', vehicle_make='Mitsubishi', vehicle_model='Tredia', model_year=1985, employer='Collier-Lakin', department='Services', employee_id=777092355, last_updated=datetime.date(2017, 11, 19), created=datetime.date(2016, 7, 31))
# ssn_match_info(ssn=201531249, first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish', vehicle_make='Acura', vehicle_model='NSX', model_year=1996, employer='Collier-Wisozk', department='Legal', employee_id=403440604, last_updated=datetime.date(2017, 11, 25), created=datetime.date(2016, 10, 7))
# ssn_match_info(ssn=202841146, first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans', vehicle_make='Chrysler', vehicle_model='LHS', model_year=2000, employer='Collins Inc', department='Training', employee_id=294800617, last_updated=datetime.date(2017, 4, 1), created=datetime.date(2016, 7, 21))
# ssn_match_info(ssn=203357648, first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian', vehicle_make='Volvo', vehicle_model='960', model_year=1992, employer='Collins Blick and Rippin', department='Marketing', employee_id=91706408, last_updated=datetime.date(2017, 12, 1), created=datetime.date(2016, 8, 2))
# ssn_match_info(ssn=205697375, first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian', vehicle_make='Subaru', vehicle_model='Outback', model_year=2011, employer='Collins-Schulist', department='Marketing', employee_id=903382110, last_updated=datetime.date(2018, 2, 27), created=datetime.date(2016, 5, 19))
# ssn_match_info(ssn=205872423, first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu', vehicle_make='Chevrolet', vehicle_model='Express 2500', model_year=1999, employer='Conn Group', department='Training', employee_id=97105416, last_updated=datetime.date(2018, 1, 1), created=datetime.date(2016, 2, 16))
# ssn_match_info(ssn=206286674, first_name='Con', last_name='Mansbridge', gender='Male', language='Haitian Creole', vehicle_make='Mitsubishi', vehicle_model='Chariot', model_year=1994, employer='Connelly Group', department='Research and Development', employee_id=987952860, last_updated=datetime.date(2017, 10, 14), created=datetime.date(2016, 8, 1))
# ssn_match_info(ssn=206838848, first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz', vehicle_make='Volvo', vehicle_model='S60', model_year=2011, employer='Connelly-Nolan', department='Training', employee_id=564133362, last_updated=datetime.date(2017, 11, 8), created=datetime.date(2016, 4, 11))
# ssn_match_info(ssn=208742166, first_name='Tiebold', last_name='Gherarducci', gender='Male', language='Croatian', vehicle_make='Lexus', vehicle_model='LX', model_year=1999, employer='Conroy and Sons', department='Sales', employee_id=661939780, last_updated=datetime.date(2017, 1, 24), created=datetime.date(2016, 2, 28))
# ssn_match_info(ssn=208805879, first_name='Rockie', last_name='Fryd', gender='Male', language='Korean', vehicle_make='Mercury', vehicle_model='Mountaineer', model_year=2009, employer='Conroy Inc', department='Engineering', employee_id=788420673, last_updated=datetime.date(2017, 10, 16), created=datetime.date(2016, 3, 31))
# ssn_match_info(ssn=209508146, first_name='Kenna', last_name='Meryett', gender='Female', language='Czech', vehicle_make='Chevrolet', vehicle_model='Sportvan G20', model_year=1992, employer='Conroy LLC', department='Legal', employee_id=450095737, last_updated=datetime.date(2018, 3, 13), created=datetime.date(2016, 4, 10))
# ...
# ssn_match_info(ssn=857375902, first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi', vehicle_make='Lotus', vehicle_model='Esprit', model_year=1996, employer='Will Inc', department='Product Management', employee_id=700007392, last_updated=datetime.date(2018, 1, 20), created=datetime.date(2016, 10, 23))
# ssn_match_info(ssn=858037735, first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh', vehicle_make='Porsche', vehicle_model='944', model_year=1984, employer='Will Crist and Jakubowski', department='Marketing', employee_id=224425487, last_updated=datetime.date(2017, 4, 30), created=datetime.date(2016, 9, 4))
# ssn_match_info(ssn=858279190, first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian', vehicle_make='Suzuki', vehicle_model='Swift', model_year=1997, employer="Will Lemke and O'Hara", department='Marketing', employee_id=687719884, last_updated=datetime.date(2017, 2, 6), created=datetime.date(2016, 12, 25))
# ssn_match_info(ssn=860670256, first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik', vehicle_make='Toyota', vehicle_model='Tacoma', model_year=2001, employer='Will-Auer', department='Support', employee_id=417214465, last_updated=datetime.date(2017, 1, 9), created=datetime.date(2016, 2, 6))
# ssn_match_info(ssn=860892570, first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish', vehicle_make='Dodge', vehicle_model='Dakota', model_year=2007, employer='Williamson-King', department='Services', employee_id=692518819, last_updated=datetime.date(2017, 4, 15), created=datetime.date(2016, 6, 22))
# ssn_match_info(ssn=861506716, first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian', vehicle_make='BMW', vehicle_model='M5', model_year=2007, employer='Williamson-Lemke', department='Accounting', employee_id=809563373, last_updated=datetime.date(2018, 3, 30), created=datetime.date(2016, 9, 16))
# ssn_match_info(ssn=862200653, first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish', vehicle_make='Mazda', vehicle_model='B-Series', model_year=2002, employer='Windler Group', department='Legal', employee_id=162190623, last_updated=datetime.date(2017, 5, 3), created=datetime.date(2016, 2, 4))
# ssn_match_info(ssn=864229364, first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian', vehicle_make='Acura', vehicle_model='ZDX', model_year=2011, employer='Windler Group', department='Accounting', employee_id=947813244, last_updated=datetime.date(2017, 2, 4), created=datetime.date(2016, 12, 28))
# ssn_match_info(ssn=864917489, first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama', vehicle_make='Pontiac', vehicle_model='Grand Am', model_year=2004, employer='Windler Inc', department='Sales', employee_id=536449997, last_updated=datetime.date(2017, 2, 3), created=datetime.date(2016, 2, 14))
# ssn_match_info(ssn=866181440, first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento', vehicle_make='Volvo', vehicle_model='S60', model_year=2002, employer='Windler Marks and Haley', department='Services', employee_id=546271885, last_updated=datetime.date(2017, 5, 31), created=datetime.date(2016, 2, 2))
# ssn_match_info(ssn=866530625, first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian', vehicle_make='Chevrolet', vehicle_model='Blazer', model_year=1997, employer='Windler-Hudson', department='Accounting', employee_id=357283373, last_updated=datetime.date(2018, 2, 24), created=datetime.date(2016, 12, 15))
# ssn_match_info(ssn=867116007, first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam', vehicle_make='Volvo', vehicle_model='S80', model_year=2001, employer='Wintheiser-Dach', department='Research and Development', employee_id=237767142, last_updated=datetime.date(2018, 1, 25), created=datetime.date(2016, 10, 31))
# ssn_match_info(ssn=867136844, first_name='Clo', last_name='Skacel', gender='Female', language='Armenian', vehicle_make='Land Rover', vehicle_model='Range Rover', model_year=1986, employer='Wintheiser-Nader', department='Engineering', employee_id=861251169, last_updated=datetime.date(2017, 10, 31), created=datetime.date(2016, 7, 17))
# ssn_match_info(ssn=867882360, first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha', vehicle_make='Ford', vehicle_model='F-Series', model_year=1987, employer='Wisoky Fritsch and Turcotte', department='Legal', employee_id=822479792, last_updated=datetime.date(2018, 3, 11), created=datetime.date(2016, 11, 4))
# ssn_match_info(ssn=868321805, first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian', vehicle_make='Chevrolet', vehicle_model='Colorado', model_year=2007, employer='Wisoky Ziemann and West', department='Training', employee_id=199467528, last_updated=datetime.date(2017, 9, 29), created=datetime.date(2016, 11, 14))
# ssn_match_info(ssn=870126609, first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana', vehicle_make='Mercedes-Benz', vehicle_model='W201', model_year=1991, employer='Wisoky-Trantow', department='Human Resources', employee_id=403551397, last_updated=datetime.date(2017, 1, 19), created=datetime.date(2016, 6, 24))
# ssn_match_info(ssn=870931121, first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew', vehicle_make='Mitsubishi', vehicle_model='Pajero', model_year=1998, employer='Wisozk Bergnaum and Fahey', department='Accounting', employee_id=83337151, last_updated=datetime.date(2017, 3, 3), created=datetime.date(2016, 6, 21))
# ssn_match_info(ssn=871993191, first_name='Susann', last_name='Walrond', gender='Female', language='Amharic', vehicle_make='Toyota', vehicle_model='Sienna', model_year=2000, employer='Wisozk Daniel and Becker', department='Research and Development', employee_id=46398608, last_updated=datetime.date(2017, 5, 8), created=datetime.date(2016, 2, 27))
# ssn_match_info(ssn=872189267, first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese', vehicle_make='Audi', vehicle_model='A4', model_year=2010, employer='Wisozk Ward and Hodkiewicz', department='Human Resources', employee_id=34271568, last_updated=datetime.date(2018, 3, 22), created=datetime.date(2016, 4, 27))
# ssn_match_info(ssn=872491288, first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish', vehicle_make='Acura', vehicle_model='Integra', model_year=1997, employer='Witting Hartmann and Leffler', department='Engineering', employee_id=779709375, last_updated=datetime.date(2017, 12, 6), created=datetime.date(2016, 6, 10))
# ssn_match_info(ssn=873364733, first_name='Locke', last_name='Staries', gender='Male', language='Moldovan', vehicle_make='Austin', vehicle_model='Mini Cooper', model_year=1964, employer='Witting Schuster and Barton', department='Research and Development', employee_id=544161357, last_updated=datetime.date(2017, 7, 23), created=datetime.date(2016, 7, 8))
# ssn_match_info(ssn=875189454, first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu', vehicle_make='Mitsubishi', vehicle_model='Diamante', model_year=1993, employer='Witting-Skiles', department='Product Management', employee_id=938471220, last_updated=datetime.date(2017, 3, 14), created=datetime.date(2016, 8, 19))
# ssn_match_info(ssn=875750495, first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish', vehicle_make='Hyundai', vehicle_model='Tiburon', model_year=2000, employer='Wiza Group', department='Sales', employee_id=682794098, last_updated=datetime.date(2017, 12, 3), created=datetime.date(2016, 6, 12))
# ssn_match_info(ssn=878128265, first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi', vehicle_make='Chrysler', vehicle_model='Concorde', model_year=1998, employer='Wolf LLC', department='Engineering', employee_id=538370994, last_updated=datetime.date(2017, 1, 11), created=datetime.date(2016, 3, 14))
# ssn_match_info(ssn=880224449, first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri', vehicle_make='Toyota', vehicle_model='Camry', model_year=2008, employer='Wolf Gerhold and Dickens', department='Marketing', employee_id=156603582, last_updated=datetime.date(2017, 1, 13), created=datetime.date(2016, 6, 11))
# ssn_match_info(ssn=881195974, first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho', vehicle_make='Infiniti', vehicle_model='G', model_year=2004, employer='Wolf Hermann and Frami', department='Training', employee_id=884502070, last_updated=datetime.date(2018, 2, 4), created=datetime.date(2016, 10, 5))
# ssn_match_info(ssn=881887308, first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga', vehicle_make='Subaru', vehicle_model='SVX', model_year=1994, employer='Wolf Murray and Koepp', department='Product Management', employee_id=488015766, last_updated=datetime.date(2017, 8, 11), created=datetime.date(2016, 1, 18))
# ssn_match_info(ssn=881957180, first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian', vehicle_make='BMW', vehicle_model='M6', model_year=2009, employer='Wolff Metz and Gorczany', department='Accounting', employee_id=116978970, last_updated=datetime.date(2018, 1, 29), created=datetime.date(2016, 11, 24))
# ssn_match_info(ssn=882495290, first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian', vehicle_make='GMC', vehicle_model='Savana 3500', model_year=2011, employer='Wuckert Inc', department='Accounting', employee_id=646834709, last_updated=datetime.date(2017, 2, 10), created=datetime.date(2016, 8, 27))
# ssn_match_info(ssn=884611852, first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian', vehicle_make='Plymouth', vehicle_model='Neon', model_year=1996, employer='Wunsch Johnson and Kiehn', department='Marketing', employee_id=476501802, last_updated=datetime.date(2017, 1, 9), created=datetime.date(2016, 3, 18))
# ssn_match_info(ssn=887417878, first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil', vehicle_make='Lexus', vehicle_model='GS', model_year=2013, employer='Wunsch-Gleason', department='Services', employee_id=283015726, last_updated=datetime.date(2017, 3, 27), created=datetime.date(2016, 9, 14))
# ssn_match_info(ssn=887839002, first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin', vehicle_make='Audi', vehicle_model='S6', model_year=2011, employer='Wunsch-Ruecker', department='Accounting', employee_id=308759158, last_updated=datetime.date(2017, 12, 19), created=datetime.date(2016, 5, 30))
# ssn_match_info(ssn=888507008, first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha', vehicle_make='Nissan', vehicle_model='Armada', model_year=2008, employer='Wunsch-Walsh', department='Marketing', employee_id=588512115, last_updated=datetime.date(2018, 3, 6), created=datetime.date(2016, 6, 9))
# ssn_match_info(ssn=888537684, first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian', vehicle_make='Volkswagen', vehicle_model='Jetta', model_year=1991, employer='Wyman and Sons', department='Support', employee_id=274093007, last_updated=datetime.date(2017, 9, 5), created=datetime.date(2016, 2, 12))
# ssn_match_info(ssn=888824928, first_name='Billye', last_name='Legat', gender='Female', language='Icelandic', vehicle_make='Volvo', vehicle_model='S60', model_year=2005, employer='Yost and Sons', department='Sales', employee_id=77718175, last_updated=datetime.date(2017, 12, 8), created=datetime.date(2016, 11, 9))
# ssn_match_info(ssn=890289962, first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua', vehicle_make='GMC', vehicle_model='Savana 1500', model_year=2000, employer='Yundt Wehner and Brown', department='Legal', employee_id=550777439, last_updated=datetime.date(2018, 1, 6), created=datetime.date(2016, 2, 22))
# ssn_match_info(ssn=893120901, first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya', vehicle_make='Lotus', vehicle_model='Esprit', model_year=1991, employer='Zboncak and Sons', department='Product Management', employee_id=853010287, last_updated=datetime.date(2018, 3, 27), created=datetime.date(2016, 6, 14))
# ssn_match_info(ssn=893177318, first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz', vehicle_make='Chevrolet', vehicle_model='Lumina', model_year=1995, employer='Zboncak-Gulgowski', department='Marketing', employee_id=50368584, last_updated=datetime.date(2017, 7, 23), created=datetime.date(2016, 2, 28))
# ssn_match_info(ssn=894810628, first_name='Ree', last_name='Mordue', gender='Female', language='Tswana', vehicle_make='Kia', vehicle_model='Sedona', model_year=2012, employer='Zemlak LLC', department='Research and Development', employee_id=868667896, last_updated=datetime.date(2017, 3, 7), created=datetime.date(2016, 7, 9))
# ssn_match_info(ssn=895261658, first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic', vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=2003, employer='Zemlak Heathcote and Turner', department='Training', employee_id=865333401, last_updated=datetime.date(2017, 4, 1), created=datetime.date(2016, 11, 22))
# ssn_match_info(ssn=895265515, first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho', vehicle_make='Acura', vehicle_model='TL', model_year=1999, employer='Zemlak-Olson', department='Business Development', employee_id=462886707, last_updated=datetime.date(2017, 5, 13), created=datetime.date(2016, 3, 24))
# ssn_match_info(ssn=897767070, first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali', vehicle_make='BMW', vehicle_model='X3', model_year=2011, employer='Ziemann Denesik and Casper', department='Research and Development', employee_id=716097002, last_updated=datetime.date(2017, 11, 27), created=datetime.date(2016, 12, 12))
# ssn_match_info(ssn=898033165, first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic', vehicle_make='Toyota', vehicle_model='Xtra', model_year=1994, employer='Ziemann-Lowe', department='Sales', employee_id=730391148, last_updated=datetime.date(2017, 6, 1), created=datetime.date(2016, 7, 20))
# ssn_match_info(ssn=898868860, first_name='Hershel', last_name='Few', gender='Male', language='Gagauz', vehicle_make='Lotus', vehicle_model='Esprit', model_year=2003, employer='Zieme LLC', department='Product Management', employee_id=656531918, last_updated=datetime.date(2017, 7, 3), created=datetime.date(2016, 11, 23))
# ssn_match_info(ssn=899091766, first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino', vehicle_make='Toyota', vehicle_model='Camry', model_year=2012, employer='Zieme Beatty and Hintz', department='Engineering', employee_id=261194300, last_updated=datetime.date(2017, 7, 31), created=datetime.date(2016, 10, 27))
# ssn_match_info(ssn=899397179, first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek', vehicle_make='Infiniti', vehicle_model='FX', model_year=2006, employer='Zieme-Yundt', department='Human Resources', employee_id=634840862, last_updated=datetime.date(2017, 8, 2), created=datetime.date(2016, 7, 27))
# ssn_match_info(ssn=899397378, first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian', vehicle_make='Toyota', vehicle_model='Land Cruiser', model_year=1999, employer='Zulauf Inc', department='Accounting', employee_id=467067366, last_updated=datetime.date(2017, 3, 27), created=datetime.date(2016, 9, 4))
# ssn_match_info(ssn=899476116, first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum', vehicle_make='Volkswagen', vehicle_model='Phaeton', model_year=2005, employer='Zulauf Hudson and Wisozk', department='Research and Development', employee_id=391896194, last_updated=datetime.date(2017, 6, 10), created=datetime.date(2016, 4, 29))

# %% [markdown]
# # Goal 3

# %%
personal_data = gen_fun(personal_info, personal_info_type, 'personal_info')
vehicles_data = gen_fun(vehicles,vehicles_type, 'vehicles')
status_data = gen_fun(update_status,status_type, 'update_status')
employment_data = gen_fun(employment, employment_type, 'employment')

# %%
from itertools import islice
ssn_matched=ssn_match()

def stale_records(input_date):
    date = datetime.strptime(input_date, '%d-%m-%Y').date()
    for data in islice(ssn_matched, 1000):
        if data.last_updated < date:
            yield data
        if data.ssn == 899476116:
            print('End of records')

# %%
input_date = '03-01-2017'
stale_record=stale_records(input_date)

# %%
for data in stale_record:
    print(data.ssn, data.first_name, data.last_updated)
# Out:
# 390743062 Cara 2017-01-01
# 644708292 Glyn 2017-01-02
# 669129323 Peter 2017-01-02
# End of records

# %% [markdown]
# # Goal 4

# %%
personal_data = gen_fun(personal_info, personal_info_type, 'personal_info')
vehicles_data = gen_fun(vehicles,vehicles_type, 'vehicles')
status_data = gen_fun(update_status,status_type, 'update_status')
employment_data = gen_fun(employment, employment_type, 'employment')
all_record = ssn_match()

make_count_male = dict()
make_count_female = dict()
for _ in islice(all_record,1000):
    if _.gender == 'Male':
        make_count_male[_.vehicle_make] = make_count_male[_.vehicle_make] + 1 if _.vehicle_make in make_count_male else 1
    else:
        make_count_female[_.vehicle_make] = make_count_female[_.vehicle_make] + 1 if _.vehicle_make in make_count_female else 1

# %%
max_value = max(list(make_count_male.values()))
print([(k, v) for k, v in make_count_male.items() if v == max_value])
# Out:
# [('Ford', 44)]

# %%
max_value = max(list(make_count_female.values()))
print([(k, v) for k, v in make_count_female.items() if v == max_value])
# Out:
# [('Ford', 48), ('Chevrolet', 48)]
